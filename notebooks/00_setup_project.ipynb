# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

PROJECT_ROOT = "/content/drive/MyDrive/bigdata-gbl-quiz"
PROJECT_ROOT
# Out:
# '/content/drive/MyDrive/bigdata-gbl-quiz'

# %%
folders = [
    "data/raw",
    "data/processed",
    "notebooks",
    "figures",
    "report",
    "src"
]

for f in folders:
    os.makedirs(os.path.join(PROJECT_ROOT, f), exist_ok=True)

print("✅ Folder structure created inside:", PROJECT_ROOT)
# Out:
# ✅ Folder structure created inside: /content/drive/MyDrive/bigdata-gbl-quiz

# %%
for root, dirs, files in os.walk(PROJECT_ROOT):
    level = root.replace(PROJECT_ROOT, "").count(os.sep)
    indent = "  " * level
    print(f"{indent}{os.path.basename(root)}/")
# Out:
# bigdata-gbl-quiz/
#   data/
#     raw/
#     processed/
#   notebooks/
#   figures/
#   report/
#   src/
